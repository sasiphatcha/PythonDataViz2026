# %% [markdown]
# <a href="https://colab.research.google.com/github/sasiphatcha/PythonDataViz2026/blob/main/hw7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# HW7 673020639-5

# %% [markdown]
# ##สร้างตารางใหม่ที่ค่า sex เป็น missing ทั้งหมด

# %% [markdown]
# ดึงไฟล์

# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/DataViz"
covid = os.path.join(path,'confirmed-cases-since-120465.csv')
print(covid)
# Out:
# /content/drive/MyDrive/DataViz/confirmed-cases-since-120465.csv

# %%
data = pd.read_csv(covid)
data.head()
# Out:
# /tmp/ipykernel_1004/124259832.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(covid)
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  3905873     12/4/2022     11/4/2022  หญิง  54.0   ปี    Thailand
# 1  3905874     12/4/2022     11/4/2022  หญิง  36.0   ปี    Thailand
# 2  3905875     12/4/2022     11/4/2022  หญิง  31.0   ปี    Thailand
# 3  3905876     12/4/2022     11/4/2022   ชาย  37.0   ปี    Thailand
# 4  3905877     12/4/2022     11/4/2022  หญิง  33.0   ปี    Thailand
#
#   province_of_isolation                  risk province_of_onset  \
# 0             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 1             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 2             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 3             เชียงใหม่  อยู่ระหว่างการสอบสวน               NaN
# 4             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
#
# ...

# %%
data[pd.isnull(data["sex"])]
# Out:
#             No. announce_date Notified date  sex   age Unit nationality  \
# 704     3906577     12/4/2022     11/4/2022  NaN   NaN  NaN    Thailand
# 705     3906578     12/4/2022     11/4/2022  NaN   NaN  NaN    Thailand
# 706     3906579     12/4/2022     11/4/2022  NaN   NaN  NaN    Thailand
# 707     3906580     12/4/2022     11/4/2022  NaN   NaN  NaN    Thailand
# 708     3906581     12/4/2022     11/4/2022  NaN   NaN  NaN    Thailand
# ...         ...           ...           ...  ...   ...  ...         ...
# 353978  4259851      1/5/2022     30/4/2022  NaN  35.0   ปี         NaN
# 353979  4259852      1/5/2022     30/4/2022  NaN   NaN  NaN         NaN
# 353980  4259853      1/5/2022     30/4/2022  NaN  25.0   ปี         NaN
# 353981  4259854      1/5/2022     30/4/2022  NaN  25.0   ปี         NaN
# 353982  4259855      1/5/2022     30/4/2022  NaN  36.0   ปี         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...
