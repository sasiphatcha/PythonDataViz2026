# %% [markdown]
# <a href="https://colab.research.google.com/github/sasiphatcha/PythonDataViz2026/blob/main/PythonDataViz2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## นางสาวศศิภัทชา เจียรเจริญกิจ

# %%
print('67320639-5')
# Out:
# 67320639-5
