# %% [markdown]
# <a href="https://colab.research.google.com/github/sasiphatcha/PythonDataViz2026/blob/main/hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW6 673020639-5

# %% [markdown]
# ##
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**

# %% [markdown]
# ### ดึงไฟล์

# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/DataViz"
covid = os.path.join(path,'confirmed-cases-since-120465.csv')
print(covid)
# Out:
# /content/drive/MyDrive/DataViz/confirmed-cases-since-120465.csv

# %%
data = pd.read_csv(covid)
data.head()
# Out:
# /tmp/ipykernel_7771/124259832.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(covid)
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  3905873     12/4/2022     11/4/2022  หญิง  54.0   ปี    Thailand
# 1  3905874     12/4/2022     11/4/2022  หญิง  36.0   ปี    Thailand
# 2  3905875     12/4/2022     11/4/2022  หญิง  31.0   ปี    Thailand
# 3  3905876     12/4/2022     11/4/2022   ชาย  37.0   ปี    Thailand
# 4  3905877     12/4/2022     11/4/2022  หญิง  33.0   ปี    Thailand
#
#   province_of_isolation                  risk province_of_onset  \
# 0             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 1             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 2             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 3             เชียงใหม่  อยู่ระหว่างการสอบสวน               NaN
# 4             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
#
# ...

# %% [markdown]
# ###1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด

# %% [markdown]
# ผู้หญิง

# %%
data1 = data[['sex','age','province_of_isolation']]
data1
# Out:
#          sex   age province_of_isolation
# 0       หญิง  54.0             เชียงใหม่
# 1       หญิง  36.0             เชียงใหม่
# 2       หญิง  31.0             เชียงใหม่
# 3        ชาย  37.0             เชียงใหม่
# 4       หญิง  33.0             เชียงใหม่
# ...      ...   ...                   ...
# 356607   ชาย   NaN              พิษณุโลก
# 356608   ชาย   NaN              ปทุมธานี
# 356609  หญิง   NaN              ปทุมธานี
# 356610  หญิง   NaN              ปทุมธานี
# 356611   ชาย   NaN               ขอนแก่น
#
# [356612 rows x 3 columns]

# %%
female = data1[data1["sex"] == "หญิง"]
female
# Out:
#          sex   age province_of_isolation
# 0       หญิง  54.0             เชียงใหม่
# 1       หญิง  36.0             เชียงใหม่
# 2       หญิง  31.0             เชียงใหม่
# 4       หญิง  33.0             เชียงใหม่
# 5       หญิง  12.0             เชียงใหม่
# ...      ...   ...                   ...
# 356592  หญิง  27.0         กรุงเทพมหานคร
# 356595  หญิง  35.0         กรุงเทพมหานคร
# 356597  หญิง   NaN         กรุงเทพมหานคร
# 356609  หญิง   NaN              ปทุมธานี
# 356610  หญิง   NaN              ปทุมธานี
#
# [203340 rows x 3 columns]

# %%
# 1. แปลงคอลัมน์ age ให้เป็นตัวเลข (ข้อความที่ไม่ใช่ตัวเลขจะกลายเป็น NaN)
female['age'] = pd.to_numeric(female['age'], errors='coerce')
mean_age_fm = female['age'].mean()
print(mean_age_fm)
# Out:
# 41.849625900589864
# /tmp/ipykernel_7771/2403984497.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female['age'] = pd.to_numeric(female['age'], errors='coerce')

# %% [markdown]
# ผู้ชาย

# %%
male = data1[data1["sex"] == "ชาย"]
male
# Out:
#         sex   age province_of_isolation
# 3       ชาย  37.0             เชียงใหม่
# 6       ชาย  32.0             เชียงใหม่
# 9       ชาย  42.0             เชียงใหม่
# 11      ชาย  41.0             เชียงใหม่
# 13      ชาย  37.0             เชียงใหม่
# ...     ...   ...                   ...
# 356605  ชาย   NaN              พิษณุโลก
# 356606  ชาย   NaN              พิษณุโลก
# 356607  ชาย   NaN              พิษณุโลก
# 356608  ชาย   NaN              ปทุมธานี
# 356611  ชาย   NaN               ขอนแก่น
#
# [135617 rows x 3 columns]

# %%
# 1. แปลงคอลัมน์ age ให้เป็นตัวเลข (ข้อความที่ไม่ใช่ตัวเลขจะกลายเป็น NaN)
male['age'] = pd.to_numeric(male['age'], errors='coerce')
mean_age_m = male['age'].mean()
print(mean_age_m)
# Out:
# 39.41913811289394
# /tmp/ipykernel_7771/900756738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male['age'] = pd.to_numeric(male['age'], errors='coerce')

# %% [markdown]
# ###2. คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %%
kk_fm = female[female["province_of_isolation"] == "ขอนแก่น"]
kk_fm
# Out:
#          sex   age province_of_isolation
# 10537   หญิง  32.0               ขอนแก่น
# 10538   หญิง  56.0               ขอนแก่น
# 10540   หญิง   4.0               ขอนแก่น
# 10541   หญิง  41.0               ขอนแก่น
# 10543   หญิง  83.0               ขอนแก่น
# ...      ...   ...                   ...
# 350025  หญิง  48.0               ขอนแก่น
# 350027  หญิง  30.0               ขอนแก่น
# 350028  หญิง  24.0               ขอนแก่น
# 350029  หญิง  38.0               ขอนแก่น
# 350030  หญิง  27.0               ขอนแก่น
#
# [8060 rows x 3 columns]

# %%
kk_fm['age'].mean()
# Out:
# np.float64(40.69853950817626)

# %%
kk_m = male[male["province_of_isolation"] == "ขอนแก่น"]
kk_m
# Out:
#         sex   age province_of_isolation
# 10539   ชาย   8.0               ขอนแก่น
# 10542   ชาย  67.0               ขอนแก่น
# 10553   ชาย  64.0               ขอนแก่น
# 10557   ชาย  73.0               ขอนแก่น
# 10560   ชาย  89.0               ขอนแก่น
# ...     ...   ...                   ...
# 350017  ชาย  41.0               ขอนแก่น
# 350022  ชาย  14.0               ขอนแก่น
# 350024  ชาย  52.0               ขอนแก่น
# 350026  ชาย  64.0               ขอนแก่น
# 356611  ชาย   NaN               ขอนแก่น
#
# [4682 rows x 3 columns]

# %%
kk_m['age'].mean()
# Out:
# np.float64(37.95105503589297)

# %% [markdown]
# ###3. หาจำนวนผู้ป่วยที่เป็นคน "คนต่างชาติเดินทางมาจากต่างประเทศ"

# %%
other = data[data['nationality'] != 'Thailand']
other
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 91      3905964     12/4/2022     11/4/2022   ชาย  69.0   ปี         NaN
# 92      3905965     12/4/2022     11/4/2022  หญิง  28.0   ปี         NaN
# 226     3906099     12/4/2022     11/4/2022  หญิง   1.0   ปี         NaN
# 229     3906102     12/4/2022     11/4/2022   ชาย  13.0   ปี         NaN
# 231     3906104     12/4/2022     11/4/2022   ชาย  70.0   ปี         NaN
# ...         ...           ...           ...   ...   ...  ...         ...
# 356607  4262480      1/5/2022     30/4/2022   ชาย   NaN  NaN         NaN
# 356608  4262481      1/5/2022     30/4/2022   ชาย   NaN  NaN         NaN
# 356609  4262482      1/5/2022     30/4/2022  หญิง   NaN  NaN         NaN
# 356610  4262483      1/5/2022     30/4/2022  หญิง   NaN  NaN         NaN
# 356611  4262484      1/5/2022     30/4/2022   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...

# %%
data[(data['nationality'] != "Thailand") & (data['risk'] == "คนที่มาจากต่างประเทศ" ) ].shape
# Out:
# (0, 11)
